# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *
import cmath
import scipy as sp
# %matplotlib inline

# %%
3 + 2j
# Out:
# (3+2j)

# %%
a = 3
b = 3
z = a + b * 1j
print('z = ', z)
print('The type of the variable is ', type(z))
# Out:
# z =  (3+3j)
# The type of the variable is  <class 'complex'>

# %%
(2.75+3.69j)*(8.55-6.13j)
# Out:
# (46.1322+14.692000000000004j)

# %%
a = 2.75*8.55

print(a)
# Out:
# 23.512500000000003

# %%
b = 2.75*6.13

print(b)
# Out:
# 16.857499999999998

# %%
c = 3.69*8.55

print(c)
# Out:
# 31.549500000000002

# %%
d = 3.69*6.13

print(d)
# Out:
# 22.619699999999998

# %%
a+d
# Out:
# 46.1322

# %%
c-b
# Out:
# 14.692000000000004

# %%
np.exp(4j)
# Out:
# (-0.65364362086361194-0.7568024953079282j)

# %%
(7.51 - 9.15j)/(4.43 + 9.64j)
# Out:
# (-0.4880897698448308-1.0033441577191493j)

# %%
h = 1.4 * np.exp(5.32j)
h
# Out:
# (0.79927078585823497-1.1494199453957457j)

# %% [markdown]
# ##2. Shapes created by the Joukowski transformation

# %% [markdown]
# ###2.1. Circle :- centre = 0, 0 :- radius = 1.5 :- c = 1

# %%
c = 1 # constant for Joukowski transformation

# %%
r = 1.5 # radius of circle

# %%
ang = np.linspace(0, 2*np.pi, 100) # angle array for circle

# %%
def xy(r,phi):
    return r*np.cos(phi), r*np.sin(phi) # function to output x, y coordinates of circle from polar coordinates

# plot circle
fig = plt.figure()
ax = fig.add_subplot(111,aspect='equal')  

ax.plot( *xy(r,ang), c='r',ls='-' )
plt.show()

# %%
rect = xy(r, ang) # rectangular coordinates of circle

# %%
complex_coords = rect[0] + 1j*rect[1] # transform circle coordinates into complex numbers

# %%
def map(x, const):
    return x + const**2/x # Joukowski transformation function

# %%
ξ = map(complex_coords, c)

# %%
plt.scatter(ξ.real,ξ.imag) # plot Joukowski transform of cylinder

# %% [markdown]
# ###2.2. Circle :- centre x_c, y_c = c - R, 0 :- c < R < 2c

# %%
c2 = 1.2 # constant for Joukowski transformation

# %%
r2 = 1.7 # radius of circle

# %%
x_c, y_c = c2-r2, 0 # circle centre

# %%
def xy2(r,phi):
    return r*np.cos(phi)+x_c, r*np.sin(phi)+y_c # function to output x, y coordinates of circle from polar coordinates


# plot circle
fig = plt.figure()
ax = fig.add_subplot(111,aspect='equal')  

ax.plot( *xy(r2,ang), c='r',ls='-' )
plt.show()

# %%
rect2 = xy2(r2, ang) # rectangular coordinates of circle

# %%
complex_coords2 = rect2[0] + 1j*rect2[1] # transform circle coordinates into complex numbers

# %%
ξ2 = map(complex_coords2, c2)

# %%
plt.scatter(ξ2.real,ξ2.imag) # plot Joukowski transform of cylinder

# %% [markdown]
# ###2.3. Circle :- centre x_c, y_c = -0.1, 0.1 : R^2 = (c - x_c)^2 + y_c^2

# %%
c3 = 1 # constant for Joukowski transformation

# %%
x_c3, y_c3 = -0.1, 0.1 # circle centre

# %%
r3 = np.sqrt((c3-x_c3)**2 + y_c3**2)
r3
# Out:
# 1.1045361017187261

# %%
def xy3(r,phi):
    return r*np.cos(phi)+x_c3, r*np.sin(phi)+y_c3 # function to output x, y coordinates of circle from polar coordinates


# plot circle
fig = plt.figure()
ax = fig.add_subplot(111,aspect='equal')  

ax.plot( *xy3(r3,ang), c='r',ls='-' )
plt.show()

# %%
rect3 = xy3(r3, ang) # rectangular coordinates of circle

# %%
complex_coords3 = rect3[0] + 1j*rect3[1] # transform circle coordinates into complex numbers

# %%
ξ3 = map(complex_coords3, c3)

# %%
plt.scatter(ξ3.real,ξ3.imag) # plot Joukowski transform of cylinder

# %% [markdown]
# ##2. Grid points on the z-plane using polar coordinates

# %%
R = 5.0
r_grid = 1.15

N_r, N_θ = 100, 145                      # Number of points in each direction
r_start, r_end = r_grid, R                    # radial-direction boundaries
θ_start, θ_end = 0.0, 2*np.pi            # axial-direction boundaries
radial = np.linspace(r_start, r_end, N_r)    # computes a 1D-array for x
axial = np.linspace(θ_start, θ_end, N_θ)    # computes a 1D-array for y
radial_matrix, axial_matrix = np.meshgrid(radial, axial)              # generates a mesh grid

# %%
# plots the grid of points
size = 10
plt.figure(figsize=(size, size))
ax = plt.subplot(111, polar=True)
ax.plot(axial_matrix, radial_matrix, color='r', ls='none', marker='.')

# %%
c_grid = 1 # constant for Joukowski transformation

# %%
x_cgrid, y_cgrid = c_grid - r_grid, 0.0

def xy_grid(r,phi):
    return r*np.cos(phi)+x_cgrid, r*np.sin(phi)+y_cgrid # function to output x, y coordinates of circle from polar coordinates

# %%
rect_grid = xy_grid(radial_matrix, axial_matrix) # rectangular coordinates of circle grid

# %%
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('rect_x', fontsize=16)
plt.ylabel('rect_y', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.scatter(rect_grid[0],rect_grid[1])

# %%
complex_coords_grid = rect_grid[0] + 1j*rect_grid[1] # transform grid coordinates into complex numbers

# %%
complex_coords_grid_map = map(complex_coords_grid, c_grid)

# %%
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('ξ_x', fontsize=16)
plt.ylabel('ξ_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.scatter(complex_coords_grid_map.real,complex_coords_grid_map.imag) # plot Joukowski transform of cylinder

# %% [markdown]
# ###Evaluation of potential flow in Joukowski transformation

# %% [markdown]
# ###Potential function

# %%
R_doublet = 1.15  # doublet radius
U_freestream = 1.0 # freestream velocity

# %%
κ = R_doublet**2 * 2 * np.pi * U_freestream
κ
# Out:
# 8.309512568745001

# %%
potential_doublet = κ/(2*pi) * np.cos(axial_matrix)/radial_matrix  # doublet velocity potential

# %%
potential_freestream = U_freestream * radial_matrix * np.cos(axial_matrix) # freestream velocity potential

# %%
potential = potential_doublet + potential_freestream # potential doublet in a freestream

# %%
# plotting the contour lines of potential function
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('ξ_x', fontsize=16)
plt.ylabel('ξ_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.contour(rect_grid[0],rect_grid[1],potential, 80)

# %%
# plotting the contour lines of potential function
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('ξ_x', fontsize=16)
plt.ylabel('ξ_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.contour(complex_coords_grid_map.real,complex_coords_grid_map.imag,potential, 80)

# %% [markdown]
# ###Stream function

# %%
def get_velocity_doublet(strength, xd, yd, X, Y):
    """Returns the velocity field generated by a doublet.
    
    Arguments
    ---------
    strength -- strength of the doublet.
    xd, yd -- coordinates of the doublet.
    X, Y -- mesh grid.
    """
    u = - strength/(2*pi)*((X-xd)**2-(Y-yd)**2)/((X-xd)**2+(Y-yd)**2)**2
    v = - strength/(2*pi)*2*(X-xd)*(Y-yd)/((X-xd)**2+(Y-yd)**2)**2
    
    return u, v

def get_stream_function_doublet(strength, xd, yd, X, Y):
    """Returns the stream-function generated by a doublet.
    
    Arguments
    ---------
    strength -- strength of the doublet.
    xd, yd -- coordinates of the doublet.
    X, Y -- mesh grid.
    """
    psi = - strength/(2*pi)*(Y-yd)/((X-xd)**2+(Y-yd)**2)
    
    return psi

# %%
# computes the velocity field from the doublet on the mesh grid
u_doublet, v_doublet = get_velocity_doublet(κ, x_cgrid, y_cgrid, rect_grid[0],rect_grid[1])

# computes the stream-function from the doublet on the mesh grid
psi_doublet = get_stream_function_doublet(κ, x_cgrid, y_cgrid, rect_grid[0],rect_grid[1])

# %%
# computes the velocity field from the freestream on the mesh grid
u_freestream = U_freestream * np.ones((N_θ, N_r), dtype=float)
v_freestream = np.zeros((N_θ, N_r), dtype=float)

# computes the stream-function from the freestream on the mesh grid
psi_freestream = U_freestream * rect_grid[1]

# %%
psi = psi_doublet + psi_freestream

# %%
# plotting the contour lines of stream function on the z plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('z_x', fontsize=16)
plt.ylabel('z_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.contour(rect_grid[0],rect_grid[1],psi, 80)

# %%
# plotting the contour lines of stream function on the xi plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.contour(complex_coords_grid_map.real,complex_coords_grid_map.imag,psi, 80)

# %%
u = u_freestream + u_doublet
v = v_freestream + v_doublet

# %%
# plots the velocity vectors on the z plane
skip = (slice(None, None, 2), slice(None, None, 2))
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('z_x', fontsize=16)
plt.ylabel('z_iy', fontsize=16)
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.quiver(rect_grid[0][skip], rect_grid[1][skip],u[skip], v[skip], angles='xy',scale=50, color='r')

# %%
z = complex_coords_grid

# %%
z.shape
# Out:
# (145, 100)

# %%
u_ξ = (u - 1j*v) / (1 - (c_grid/z)**2) # computes the velocities on the xi plane
# Out:
# /home/nd/anaconda/envs/py3k/lib/python3.3/site-packages/IPython/kernel/__main__.py:1: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':

# %%
u_ξ.shape
# Out:
# (145, 100)

# %%
# plots the velocity vectors on the xi plane
skip = (slice(None, None, 2), slice(None, None, 2))
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-2, 2)
plt.quiver(complex_coords_grid_map.real[skip],complex_coords_grid_map.imag[skip],u_ξ.real[skip], -u_ξ.imag[skip], angles='xy',scale=40, color='r')

# %%
# computes the pressure coefficient field on the z plane
cp_z = 1.0 - (u**2+v**2)/U_freestream**2

# plots the pressure coefficient field on the z plane
size = 10
plt.figure(figsize=(1.2*size, size))
plt.xlabel('z_x', fontsize=16)
plt.ylabel('z_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
contf = plt.contourf(rect_grid[0],rect_grid[1], cp_z, levels=np.linspace(-1.0, 1.0, 100), extend='both')
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-2.0, -1.0, 0.0, 1.0])

# %%
# computes the pressure coefficient field on the xi plane
cp_ξ = 1.0 - (u_ξ.real**2+u_ξ.imag**2)/U_freestream**2

# plots the pressure coefficient field on the xi plane
size = 10
plt.figure(figsize=(1.2*size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
contf = plt.contourf(complex_coords_grid_map.real,complex_coords_grid_map.imag, cp_ξ, levels=np.linspace(-1.0, 1.0, 100), extend='both')
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-2.0, -1.0, 0.0, 1.0])

# %%
u_ξ[61,0]
# Out:
# (1.1063384662852436-0.52363334929849692j)

# %%
np.abs(u_ξ[61,0])
# Out:
# 1.2240002804247827

# %%
np.nanmin(cp_ξ)
# Out:
# -0.68775567409240423

# %% [markdown]
# ## Flow over a symmetric Joukowski aerofoil with non-zero angle of attack, without circulation

# %%
α = 20 * np.pi/180 # angle of attack

# %%
c_grid_rot = 1 # constant for Joukowski transformation
x_rotc, y_rotc = 0., 0. # centre of cylinder

# %%
def xy_grid(r,phi):
    return r*np.cos(phi)+x_rotc, r*np.sin(phi)+y_rotc # function to output x, y coordinates of circle from polar coordinates

# %%
prerot_grid = xy_grid(radial_matrix, axial_matrix) # rectangular coordinates of circle grid

# %%
# rotation of coordinate system
x_dash = ((prerot_grid[0] - x_rotc)*np.cos(α)) + (prerot_grid[1] - y_rotc)*np.sin(α)
y_dash = - (prerot_grid[0] - x_rotc)*np.sin(α) + (prerot_grid[1] - y_rotc)*np.cos(α)

# %%
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('x_dash', fontsize=16)
plt.ylabel('y_dash', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.scatter(x_dash,y_dash)

# %%
# plotting the contour lines of stream function on the z' plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('zdash_x', fontsize=16)
plt.ylabel('zdash_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.contour(x_dash,y_dash,psi, 80)

# %%
# computes the velocity field from the doublet on the mesh grid
u_doublet_rot, v_doublet_rot = get_velocity_doublet(κ, x_rotc, y_rotc, x_dash, y_dash)

# computes the stream-function from the doublet on the mesh grid
psi_doublet_rot = get_stream_function_doublet(κ, x_rotc, y_rotc, x_dash, y_dash)

# %%
# computes the velocity field from the freestream on the mesh grid
u_freestream_rot = U_freestream * np.ones((N_θ, N_r), dtype=float)
v_freestream_rot = np.zeros((N_θ, N_r), dtype=float)

# computes the stream-function from the freestream on the mesh grid
psi_freestream_rot = u_freestream_rot * y_dash

# %%
psi_rot = psi_doublet_rot + psi_freestream_rot

# %%
# plotting the contour lines of stream function on the z' plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('zdash_x', fontsize=16)
plt.ylabel('zdash_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.contour(x_dash,y_dash,psi_doublet_rot, 80)

# %%
# plotting the contour lines of stream function on the z' plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('zdash_x', fontsize=16)
plt.ylabel('zdash_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.contour(x_dash,y_dash,psi_rot, 80)

# %%
# plotting the contour lines of stream function on the z' plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('zdash_x', fontsize=16)
plt.ylabel('zdash_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.contour(prerot_grid[0],prerot_grid[1],psi_rot, 80)

# %%
# plotting the contour lines of stream function on the xi plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.contour(complex_coords_grid_map.real,complex_coords_grid_map.imag,psi_rot, 180)

# %%
u_rot_dash = u_freestream_rot + u_doublet_rot
v_rot_dash = v_freestream_rot + v_doublet_rot

# %%
# plots the velocity vectors on the z plane
skip = (slice(None, None, 2), slice(None, None, 2))
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('z_dash_x', fontsize=16)
plt.ylabel('z_dash_iy', fontsize=16)
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.quiver(x_dash[skip], y_dash[skip],u_rot_dash[skip], v_rot_dash[skip], angles='xy',scale=50, color='r')

# %%
#rotate velocities from z' plane to z plane
u_rot = u_rot_dash*np.cos(α) - v_rot_dash*np.sin(α)
v_rot = u_rot_dash*np.sin(α) + v_rot_dash*np.cos(α)

# %%
# plots the velocity vectors on the z plane
skip = (slice(None, None, 2), slice(None, None, 2))
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('z_x', fontsize=16)
plt.ylabel('z_iy', fontsize=16)
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.quiver(prerot_grid[0][skip], prerot_grid[1][skip],u_rot[skip], v_rot[skip], angles='xy',scale=50, color='r')

# %%
u_rot_ξ = (u_rot - 1j*v_rot) / (1 - (c_grid_rot/z)**2) # computes the velocities on the xi plane
# Out:
# /home/nd/anaconda/envs/py3k/lib/python3.3/site-packages/IPython/kernel/__main__.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   if __name__ == '__main__':

# %%
# plots the velocity vectors on the xi plane
skip = (slice(None, None, 2), slice(None, None, 2))
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-2, 2)
plt.quiver(complex_coords_grid_map.real[skip],complex_coords_grid_map.imag[skip],u_rot_ξ.real[skip], -u_rot_ξ.imag[skip], angles='xy',scale=40, color='r')

# %%
# computes the pressure coefficient field on the z plane
cp_rot = 1.0 - (u_rot**2+v_rot**2)/U_freestream**2

# plots the pressure coefficient field on the z plane
size = 10
plt.figure(figsize=(1.2*size, size))
plt.xlabel('z_x', fontsize=16)
plt.ylabel('z_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
contf = plt.contourf(prerot_grid[0],prerot_grid[1], cp_rot, levels=np.linspace(-1.0, 1.0, 100), extend='both')
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-2.0, -1.0, 0.0, 1.0])

# %%
# computes the pressure coefficient field on the xi plane
cp_ξ_α = 1.0 - (u_rot_ξ.real**2+u_rot_ξ.imag**2)/U_freestream**2

# plots the pressure coefficient field on the xi plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-5.4, 5.1)
plt.ylim(-5.9, 5.9)
contf = plt.contourf(complex_coords_grid_map.real,complex_coords_grid_map.imag, cp_ξ_α, levels=np.linspace(-1.0, 1.0, 100), extend='both')
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-1.0, -1.0, 0.0, 1.0])

# %%
np.nanmin(np.abs(u_rot_ξ))
# Out:
# 1.5603128503913947e-16

# %%
# plots the pressure coefficient field on the xi plane
size = 10
plt.figure(figsize=(1.2*size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
contf = plt.contourf(complex_coords_grid_map.real,complex_coords_grid_map.imag, np.abs(u_rot_ξ), levels=np.linspace(0.0, 1.0, 100), extend='both')
cbar = plt.colorbar(contf)
cbar.set_label('$U$', fontsize=16)
cbar.set_ticks([-1.0, -1.0, 0.0, 1.0])

# %%
np.where(cp_ξ_α==cp_ξ_α.max())
# Out:
# (array([ 8, 80]), array([0, 0]))

# %%
def nanargmax(a):
    idx = np.argmax(a, axis=None)
    multi_idx = np.unravel_index(idx, a.shape)
    if np.isnan(a[multi_idx]):
        nan_count = np.sum(np.isnan(a))
        # In numpy < 1.8 use idx = np.argsort(a, axis=None)[-nan_count-1]
        idx = np.argpartition(a, -nan_count-1, axis=None)[-nan_count-1]
        multi_idx = np.unravel_index(idx, a.shape)
    return multi_idx

nanargmax(cp_ξ_α)
# Out:
# (8, 0)

# %%
u_rot_ξ[49,0]
# Out:
# (1.4830654150147842-0.092075495007288205j)

# %%
cp_ξ_α[74,0]
# Out:
# -0.48520991643725964

# %% [markdown]
# ##Flow over a symmetric Joukowski airfoil with non-zero angle of attack, with circulation

# %%
R_doublet
# Out:
# 1.15

# %%
gamma = - np.sin(-20/180*np.pi)*4*np.pi*U_freestream*R_doublet
gamma
# Out:
# 4.9426446603975851

# %%
def get_velocity_vortex(strength, xv, yv, X, Y):
    """Returns the velocity field generated by a vortex.
    
    Arguments
    ---------
    strength -- strength of the vortex.
    xv, yv -- coordinates of the vortex.
    X, Y -- mesh grid.
    """
    u = + strength/(2*np.pi)*(Y-yv)/((X-xv)**2+(Y-yv)**2)
    v = - strength/(2*np.pi)*(X-xv)/((X-xv)**2+(Y-yv)**2)
    return u, v

def get_stream_function_vortex(strength, xv, yv, X, Y):
    """Returns the stream-function generated by a vortex.
    
    Arguments
    ---------
    strength -- strength of the vortex.
    xv, yv -- coordinates of the vortex.
    X, Y -- mesh grid.
    """
    psi = strength/(4*np.pi)*np.log((X-xv)**2+(Y-yv)**2)
    
    return psi

# %%
# computes the velocity field on the mesh grid
u_vortex, v_vortex = get_velocity_vortex(gamma, x_rotc, y_rotc, prerot_grid[0], prerot_grid[1])

# %%
u_aerocyl = u_rot + u_vortex
v_aerocyl = v_rot + v_vortex

# %%
u_aero_ξ = (u_aerocyl - 1j*v_aerocyl) / (1 - (c_grid_rot/z)**2) # computes the velocities on the xi plane
# Out:
# /home/nd/anaconda/envs/py3k/lib/python3.3/site-packages/IPython/kernel/__main__.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   if __name__ == '__main__':

# %%
# computes the pressure coefficient field on the z plane
cp_aerocyl = 1.0 - (u_aerocyl**2+v_aerocyl**2)/U_freestream**2

# plots the pressure coefficient field on the z plane
size = 10
plt.figure(figsize=(1.2*size, size))
plt.xlabel('z_x', fontsize=16)
plt.ylabel('z_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
contf = plt.contourf(prerot_grid[0],prerot_grid[1], cp_aerocyl, levels=np.linspace(-1.0, 1.0, 100), extend='both')
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-2.0, -1.0, 0.0, 1.0])

# %%
# plots the pressure coefficient field on the xi plane
size = 10
plt.figure(figsize=(1.2*size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
contf = plt.contourf(complex_coords_grid_map.real,complex_coords_grid_map.imag, np.abs(u_aero_ξ), levels=np.linspace(0.0, 3.0, 150), extend='both')
cbar = plt.colorbar(contf)
cbar.set_label('$U$', fontsize=16)
cbar.set_ticks([-1.0, -1.0, 0.0, 3.0])

# %%
u_aero_ξ.shape
# Out:
# (145, 100)

# %%
# computes the pressure coefficient field on the xi plane
cp_aero_ξ = 1.0 - (u_aero_ξ.real**2+u_aero_ξ.imag**2)/U_freestream**2

# plots the pressure coefficient field on the xi plane
size = 10
plt.figure(figsize=(size, size))
plt.xlabel('xi_x', fontsize=16)
plt.ylabel('xi_iy', fontsize=16)
plt.xlim(-5.4, 5.1)
plt.ylim(-5.9, 5.9)
contf = plt.contourf(complex_coords_grid_map.real,complex_coords_grid_map.imag, cp_aero_ξ, levels=np.linspace(-1.0, 1.0, 100), extend='both')
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-1.0, -1.0, 0.0, 1.0])

# %%
np.where(u_aero_ξ==u_aero_ξ.min())
#np.where(u_aero_ξ==0.)
# Out:
# (array([0]), array([0]))

# %%
u_aero_ξ[91,0]
# Out:
# (0.20848311620747642+0.031988389195052508j)

# %%
cp_aero_ξ[110,0]
# Out:
# 0.49669467238347387

# %%
cp_surf = cp_aero_ξ[:,0]
ρ = 1.225

# %%
L_kuttajouk = ρ*U_freestream*κ*cos(α)
L_kuttajouk
# Out:
# 9.56527486289236

# %%
p_surf = cp_surf*0.5*ρ*U_freestream**2

# %%
from scipy.integrate import quad

def integrand(t, n, x):
    return exp(-x*t) / t**n
